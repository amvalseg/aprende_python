# %% [markdown]
# <div style="
#     background: linear-gradient(135deg, #667eea 0%, #764ba2 50%, #f093fb 100%);
#     padding: 4rem 2rem;
#     border-radius: 20px;
#     text-align: center;
#     position: relative;
#     overflow: hidden;
#     margin: 2rem 0;
#     box-shadow: 0 20px 40px rgba(0,0,0,0.2);
#     font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#     max-width: 1200px;
# ">
#   <img src="img/up.png" alt="Universidad Logo" width="200"/>
#
#   <h1 style="font-size: 2.5em; margin: 10px 0;"><strong>Bootcamp de Análisis de Datos & IA</strong></h1>
# <div style="
#     position: absolute;
#     top: 0;
#     left: 0;
#     right: 0;
#     bottom: 0;
#     background: url('data:image/svg+xml,<svg xmlns=\"http://www.w3.org/2000/svg\" viewBox=\"0 0 100 100\"><defs><pattern id=\"grid\" width=\"10\" height=\"10\" patternUnits=\"userSpaceOnUse\"><path d=\"M 10 0 L 0 0 0 10\" fill=\"none\" stroke=\"rgba(255,255,255,0.1)\" stroke-width=\"0.5\"/></pattern></defs><rect width=\"100\" height=\"100\" fill=\"url(%23grid)\"/></svg>
# </div>
#
# <div style="position: relative; z-index: 10;">
#
# <div style="
#     font-size: 5rem;
#     margin-bottom: 1rem;
#     animation: bounce 2s ease-in-out infinite;
#     filter: drop-shadow(0 10px 20px rgba(0,0,0,0.3));
# "></div>
#
# <h1 style="
#     font-size: 3.5rem;
#     font-weight: 900;
#     color: #ffffff;
#     margin: 1rem 0;
#     text-shadow: 0 0 30px rgba(255,255,255,0.8);
#     letter-spacing: 2px;
#     font-family: 'Arial Black', sans-serif;
# ">CLASE 1: LAS BASES DE PYTHON</h1>
#
# <h2 style="
#     font-size: 1.8rem;
#     color: rgba(255,255,255,0.9);
#     margin-bottom: 2rem;
#     font-weight: 400;
#     text-shadow: 0 2px 4px rgba(0,0,0,0.3);
# ">🚀 ¡Empieza nuestra aventura! 🚀</h2>
#
# <div style="
#     background: rgba(0,0,0,0.4);
#     border-radius: 15px;
#     padding: 1.5rem;
#     margin: 2rem auto;
#     max-width: 1000px;
#     border: 1px solid rgba(255,255,255,0.2);
#     backdrop-filter: blur(10px);
# ">
#     <div style="
#         color: #50fa7b;
#         font-family: 'Courier New', monospace;
#         font-size: 1.2rem;
#         text-align: left;
#     ">
#         <span style="color: #ff79c6;">>>> </span>print(<span style="color: #f1fa8c;">"¡Hola, futur@ Analista de Datos!"</span>)<br>
#         <span style="color: #50fa7b;">¡Hola, futur@ Analista!</span><br>
#         <span style="color: #ff79c6;">>>> </span>ready_to_code = <span style="color: #bd93f9;">True</span> ✨
#     </div>
# </div>
#
# <div style="
#     display: grid;
#     grid-template-columns: repeat(auto-fit, minmax(200px, 1fr));
#     gap: 1.5rem;
#     margin: 3rem 0;
#     max-width: 1000px;
#     margin-left: auto;
#     margin-right: auto;
# ">
#
# <div style="
#     background: rgba(255,255,255,0.15);
#     backdrop-filter: blur(10px);
#     border: 1px solid rgba(255,255,255,0.2);
#     border-radius: 15px;
#     padding: 1.5rem;
#     transition: transform 0.3s ease;
#     box-shadow: 0 8px 25px rgba(0,0,0,0.1);
#     max-width: 250px;
# ">
#     <div style="font-size: 2.5rem; margin-bottom: 0.5rem;">🎯</div>
#     <h3 style="
#         font-size: 1.1rem;
#         font-weight: 700;
#         color: #ffffff;
#         margin-bottom: 0.5rem;
#     ">Variables & Tipos</h3>
#     <p style="
#         font-size: 0.9rem;
#         color: rgba(255,255,255,0.8);
#         line-height: 1.4;
#     ">Domina los datos como un científico digital</p>
# </div>
#
# <div style="
#     background: rgba(255,255,255,0.15);
#     backdrop-filter: blur(10px);
#     border: 1px solid rgba(255,255,255,0.2);
#     border-radius: 15px;
#     padding: 1.5rem;
#     transition: transform 0.3s ease;
#     box-shadow: 0 8px 25px rgba(0,0,0,0.1);
#     max-width: 250px;
# ">
#     <div style="font-size: 2.5rem; margin-bottom: 0.5rem;">🎨</div>
#     <h3 style="
#         font-size: 1.1rem;
#         font-weight: 700;
#         color: #ffffff;
#         margin-bottom: 0.5rem;
#     ">Strings Ninja</h3>
#     <p style="
#         font-size: 0.9rem;
#         color: rgba(255,255,255,0.8);
#         line-height: 1.4;
#     ">Manipula texto como un verdadero artista</p>
# </div>
#
# <div style="
#     background: rgba(255,255,255,0.15);
#     backdrop-filter: blur(10px);
#     border: 1px solid rgba(255,255,255,0.2);
#     border-radius: 15px;
#     padding: 1.5rem;
#     transition: transform 0.3s ease;
#     box-shadow: 0 8px 25px rgba(0,0,0,0.1);
#     max-width: 250px;
# ">
#     <div style="font-size: 2.5rem; margin-bottom: 0.5rem;">🧮</div>
#     <h3 style="
#         font-size: 1.1rem;
#         font-weight: 700;
#         color: #ffffff;
#         margin-bottom: 0.5rem;
#     ">Super Operadores</h3>
#     <p style="
#         font-size: 0.9rem;
#         color: rgba(255,255,255,0.8);
#         line-height: 1.4;
#     ">Desbloquea poderes matemáticos épicos</p>
# </div>
#
# <div style="
#     background: rgba(255,255,255,0.15);
#     backdrop-filter: blur(10px);
#     border: 1px solid rgba(255,255,255,0.2);
#     border-radius: 15px;
#     padding: 1.5rem;
#     transition: transform 0.3s ease;
#     box-shadow: 0 8px 25px rgba(0,0,0,0.1);
#     max-width: 250px;
# ">
#     <div style="font-size: 2.5rem; margin-bottom: 0.5rem;">🏆</div>
#     <h3 style="
#         font-size: 1.1rem;
#         font-weight: 700;
#         color: #ffffff;
#         margin-bottom: 0.5rem;
#     ">Desafíos Finales</h3>
#     <p style="
#         font-size: 0.9rem;
#         color: rgba(255,255,255,0.8);
#         line-height: 1.4;
#     ">Combina todo en batallas legendarias</p>
# </div>
#
# </div>
#
# <div style="
#     background: linear-gradient(45deg, #ff6b6b, #ee5a24, #ff6b6b);
#     color: white;
#     padding: 1rem 2.5rem;
#     border: none;
#     border-radius: 50px;
#     font-size: 1.2rem;
#     font-weight: 700;
#     text-transform: uppercase;
#     letter-spacing: 2px;
#     box-shadow: 0 10px 30px rgba(255,107,107,0.4);
#     display: inline-block;
#     margin-top: 2rem;
#     cursor: pointer;
#     text-decoration: none;
#     transition: transform 0.3s ease, box-shadow 0.3s ease;
#     max-width: 1000px;
# ">
# 🚀 COMENZAR AVENTURA 🚀
# </div>
#
# <div style="
#     margin-top: 3rem;
#     padding: 1.5rem;
#     background: rgba(0,0,0,0.2);
#     border-radius: 15px;
#     border: 1px solid rgba(255,255,255,0.1);
#     max-width: 1000px;
#
# ">
#     <h3 style="color: #ffffff; margin-bottom: 1rem;">🎓 Lo que aprenderás:</h3>
# <div style="
#     display: grid;
#     grid-template-columns: repeat(auto-fit, minmax(200px, 1fr));
#     gap: 1rem;
#     justify-items: center;   /* centra el contenido en su celda */
#     text-align: center;      /* centra el texto */
#     margin: 2rem auto;
#     max-width: 900px;        /* ancho máximo del contenedor */
# ">
#     <div style="color: rgba(255,255,255,0.9); font-size: 0.95rem;">
#         ✅ Comprender la lógica básica de Python
#     </div>
#     <div style="color: rgba(255,255,255,0.9); font-size: 0.95rem;">
#         ✅ Desarrollar habilidades prácticas
#     </div>
#     <div style="color: rgba(255,255,255,0.9); font-size: 0.95rem;">
#         ✅ Fomentar el pensamiento lógico
#     </div>
#     <div style="color: rgba(255,255,255,0.9); font-size: 0.95rem;">
#         ✅ Tomar contacto con buenas prácticas
#     </div>
# </div>
#
# </div>
#
# <div style="
#     margin-top: 2rem;
#     font-size: 1.1rem;
#     color: rgba(255,255,255,0.8);
# ">
#     <strong style="color: #ffffff;">💡 Consejo del Ninja:</strong> Cada ejercicio es una nueva habilidad. <br>
#     ¡Practica, experimenta y diviértete programando! 🐍✨
# </div>
#
# </div>
# </div>
#
# ---
#
# <div style="
#     text-align: center;
#     padding: 2rem;
#     background: linear-gradient(90deg, #667eea, #764ba2);
#     border-radius: 10px;
#     margin: 2rem 0;
#     color: white;
# ">
#     <h2 style="margin: 0; font-size: 1.5rem;">⚡ ¡Prepárate para la aventura más épica de tu vida! ⚡</h2>
#     <p style="margin: 0.5rem 0 0 0; font-size: 1.1rem; opacity: 0.9;">
#         De principiante a ninja Python en una sola sesión 🥷
#     </p>
# </div>

# %% [markdown]
# <!DOCTYPE html>
# <html lang="es">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Python Básico - Aventura de Programación</title>
#     <style>
#         @import url('https://fonts.googleapis.com/css2?family=JetBrains+Mono:wght@400;600;800&family=Orbitron:wght@400;700;900&display=swap');
#
#         * {
#             margin: 0;
#             padding: 0;
#             box-sizing: border-box;
#         }
#
#         .header-container {
#             background: linear-gradient(135deg, #667eea 0%, #764ba2 50%, #f093fb 100%);
#             min-height: 100vh;
#             display: flex;
#             align-items: center;
#             justify-content: center;
#             position: relative;
#             overflow: hidden;
#             font-family: 'JetBrains Mono', monospace;
#         }
#
#         .header-container::before {
#             content: '';
#             position: absolute;
#             top: 0;
#             left: 0;
#             right: 0;
#             bottom: 0;
#             background: url('data:image/svg+xml,<svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 100 100"><defs><pattern id="grid" width="10" height="10" patternUnits="userSpaceOnUse"><path d="M 10 0 L 0 0 0 10" fill="none" stroke="rgba(255,255,255,0.1)" stroke-width="0.5"/></pattern></defs><rect width="100" height="100" fill="url(%23grid)"/></svg>');
#             animation: grid-move 20s linear infinite;
#         }
#
#         @keyframes grid-move {
#             0% { transform: translateX(0) translateY(0); }
#             100% { transform: translateX(10px) translateY(10px); }
#         }
#
#         .hero-content {
#             text-align: center;
#             z-index: 10;
#             position: relative;
#             max-width: 900px;
#             padding: 2rem;
#         }
#
#         .python-logo {
#             font-size: 6rem;
#             margin-bottom: 1rem;
#             animation: bounce 2s ease-in-out infinite;
#             filter: drop-shadow(0 10px 20px rgba(0,0,0,0.3));
#         }
#
#         @keyframes bounce {
#             0%, 20%, 50%, 80%, 100% { transform: translateY(0); }
#             40% { transform: translateY(-20px); }
#             60% { transform: translateY(-10px); }
#         }
#
#         .main-title {
#             font-family: 'Orbitron', monospace;
#             font-size: 3.5rem;
#             font-weight: 900;
#             color: #ffffff;
#             margin-bottom: 1rem;
#             text-shadow: 0 0 30px rgba(255,255,255,0.5);
#             animation: glow 2s ease-in-out infinite alternate;
#             line-height: 1.2;
#         }
#
#         @keyframes glow {
#             from { text-shadow: 0 0 30px rgba(255,255,255,0.5); }
#             to { text-shadow: 0 0 40px rgba(255,255,255,0.8), 0 0 60px rgba(102,126,234,0.6); }
#         }
#
#         .subtitle {
#             font-size: 1.4rem;
#             color: rgba(255,255,255,0.9);
#             margin-bottom: 2rem;
#             font-weight: 400;
#             text-shadow: 0 2px 4px rgba(0,0,0,0.3);
#         }
#
#         .features-grid {
#             display: grid;
#             grid-template-columns: repeat(auto-fit, minmax(250px, 1fr));
#             gap: 1.5rem;
#             margin: 3rem 0;
#         }
#
#         .feature-card {
#             background: rgba(255,255,255,0.15);
#             backdrop-filter: blur(10px);
#             border: 1px solid rgba(255,255,255,0.2);
#             border-radius: 20px;
#             padding: 1.5rem;
#             text-align: center;
#             transition: all 0.3s ease;
#             position: relative;
#             overflow: hidden;
#         }
#
#         .feature-card::before {
#             content: '';
#             position: absolute;
#             top: -50%;
#             left: -50%;
#             width: 200%;
#             height: 200%;
#             background: linear-gradient(45deg, transparent, rgba(255,255,255,0.1), transparent);
#             transform: rotate(45deg);
#             transition: all 0.6s;
#             opacity: 0;
#         }
#
#         .feature-card:hover::before {
#             animation: shimmer 1.5s ease-in-out;
#         }
#
#         @keyframes shimmer {
#             0% { transform: translateX(-100%) translateY(-100%) rotate(45deg); opacity: 0; }
#             50% { opacity: 1; }
#             100% { transform: translateX(100%) translateY(100%) rotate(45deg); opacity: 0; }
#         }
#
#         .feature-card:hover {
#             transform: translateY(-10px);
#             box-shadow: 0 20px 40px rgba(0,0,0,0.2);
#         }
#
#         .feature-icon {
#             font-size: 2.5rem;
#             margin-bottom: 0.5rem;
#             display: block;
#         }
#
#         .feature-title {
#             font-size: 1.1rem;
#             font-weight: 600;
#             color: #ffffff;
#             margin-bottom: 0.5rem;
#         }
#
#         .feature-description {
#             font-size: 0.9rem;
#             color: rgba(255,255,255,0.8);
#             line-height: 1.4;
#         }
#
#         .cta-section {
#             margin-top: 3rem;
#         }
#
#         .start-button {
#             background: linear-gradient(45deg, #ff6b6b, #ee5a24, #ff6b6b);
#             background-size: 200% 200%;
#             color: white;
#             padding: 1rem 2.5rem;
#             border: none;
#             border-radius: 50px;
#             font-size: 1.2rem;
#             font-weight: 600;
#             font-family: 'Orbitron', monospace;
#             cursor: pointer;
#             transition: all 0.3s ease;
#             text-transform: uppercase;
#             letter-spacing: 2px;
#             box-shadow: 0 10px 30px rgba(255,107,107,0.4);
#             position: relative;
#             overflow: hidden;
#         }
#
#         .start-button::before {
#             content: '';
#             position: absolute;
#             top: 0;
#             left: -100%;
#             width: 100%;
#             height: 100%;
#             background: linear-gradient(90deg, transparent, rgba(255,255,255,0.2), transparent);
#             transition: left 0.5s;
#         }
#
#         .start-button:hover::before {
#             left: 100%;
#         }
#
#         .start-button:hover {
#             animation: pulse 1.5s infinite;
#             transform: translateY(-5px);
#             box-shadow: 0 15px 40px rgba(255,107,107,0.6);
#         }
#
#         @keyframes pulse {
#             0% { background-position: 0% 50%; }
#             50% { background-position: 100% 50%; }
#             100% { background-position: 0% 50%; }
#         }
#
#         .floating-elements {
#             position: absolute;
#             top: 0;
#             left: 0;
#             width: 100%;
#             height: 100%;
#             pointer-events: none;
#             overflow: hidden;
#         }
#
#         .floating-element {
#             position: absolute;
#             font-size: 2rem;
#             color: rgba(255,255,255,0.1);
#             animation: float 15s infinite linear;
#         }
#
#         .floating-element:nth-child(1) { top: 20%; left: 10%; animation-delay: -2s; }
#         .floating-element:nth-child(2) { top: 60%; left: 80%; animation-delay: -8s; }
#         .floating-element:nth-child(3) { top: 80%; left: 20%; animation-delay: -4s; }
#         .floating-element:nth-child(4) { top: 30%; left: 70%; animation-delay: -12s; }
#         .floating-element:nth-child(5) { top: 70%; left: 50%; animation-delay: -6s; }
#
#         @keyframes float {
#             0% { transform: translateY(0px) rotate(0deg); opacity: 0; }
#             10% { opacity: 1; }
#             90% { opacity: 1; }
#             100% { transform: translateY(-100vh) rotate(360deg); opacity: 0; }
#         }
#
#         .code-snippet {
#             background: rgba(0,0,0,0.3);
#             border-radius: 10px;
#             padding: 1rem;
#             margin: 2rem 0;
#             font-family: 'JetBrains Mono', monospace;
#             font-size: 0.9rem;
#             color: #50fa7b;
#             text-align: left;
#             position: relative;
#             overflow: hidden;
#         }
#
#         .code-snippet::before {
#             content: '>>> ';
#             color: #ff79c6;
#         }
#
#         .typing-effect {
#             overflow: hidden;
#             border-right: 3px solid #50fa7b;
#             white-space: nowrap;
#             animation: typing 4s steps(40, end) infinite, blink-caret 1s step-end infinite;
#         }
#
#         @keyframes typing {
#             0%, 20% { width: 0; }
#             21%, 80% { width: 100%; }
#             81%, 100% { width: 0; }
#         }
#
#         @keyframes blink-caret {
#             0%, 50% { border-color: #50fa7b; }
#             51%, 100% { border-color: transparent; }
#         }
#
#         /* Responsive Design */
#         @media (max-width: 768px) {
#             .main-title {
#                 font-size: 2.5rem;
#             }
#
#             .subtitle {
#                 font-size: 1.1rem;
#             }
#
#             .python-logo {
#                 font-size: 4rem;
#             }
#
#             .features-grid {
#                 grid-template-columns: 1fr;
#                 gap: 1rem;
#             }
#
#             .hero-content {
#                 padding: 1rem;
#             }
#         }
#     </style>
# </head>
# <body>
#     <div class="header-container">
#         <div class="floating-elements">
#             <div class="floating-element">🐍</div>
#             <div class="floating-element">💻</div>
#             <div class="floating-element">⚡</div>
#             <div class="floating-element">🚀</div>
#             <div class="floating-element">🎯</div>
#         </div>
#
#         <div class="hero-content">
#             <div class="python-logo">🐍</div>
#             <h1 class="main-title">PYTHON BÁSICO</h1>
#             <p class="subtitle">¡Tu Primera Aventura en Programación!</p>
#
#             <div class="code-snippet">
#                 <div class="typing-effect">print("¡Hola, futuro programador!")</div>
#             </div>
#
#             <div class="features-grid">
#                 <div class="feature-card">
#                     <span class="feature-icon">🎯</span>
#                     <h3 class="feature-title">Variables & Tipos</h3>
#                     <p class="feature-description">Domina los datos como un científico digital</p>
#                 </div>
#
#                 <div class="feature-card">
#                     <span class="feature-icon">🎨</span>
#                     <h3 class="feature-title">Strings Ninja</h3>
#                     <p class="feature-description">Manipula texto como un verdadero artista</p>
#                 </div>
#
#                 <div class="feature-card">
#                     <span class="feature-icon">🧮</span>
#                     <h3 class="feature-title">Super Operadores</h3>
#                     <p class="feature-description">Desbloquea poderes matemáticos épicos</p>
#                 </div>
#
#                 <div class="feature-card">
#                     <span class="feature-icon">🏆</span>
#                     <h3 class="feature-title">Desafíos Finales</h3>
#                     <p class="feature-description">Combina todo en batallas legendarias</p>
#                 </div>
#             </div>
#
#             <div class="cta-section">
#                 <button class="start-button" onclick="scrollToContent()">
#                     🚀 COMENZAR AVENTURA
#                 </button>
#             </div>
#         </div>
#     </div>
#
#     <script>
#         function scrollToContent() {
#             // En un notebook real, esto podría hacer scroll al primer ejercicio
#             alert('¡Prepárate para la aventura de programación más épica! 🐍✨');
#         }
#
#         // Efecto de partículas adicional
#         document.addEventListener('mousemove', function(e) {
#             const cursor = document.querySelector('.cursor-trail') || createCursorTrail();
#             cursor.style.left = e.clientX + 'px';
#             cursor.style.top = e.clientY + 'px';
#         });
#
#         function createCursorTrail() {
#             const trail = document.createElement('div');
#             trail.className = 'cursor-trail';
#             trail.style.cssText = `
#                 position: fixed;
#                 width: 20px;
#                 height: 20px;
#                 border-radius: 50%;
#                 background: radial-gradient(circle, rgba(255,255,255,0.3), transparent);
#                 pointer-events: none;
#                 z-index: 1000;
#                 transition: all 0.1s ease;
#             `;
#             document.body.appendChild(trail);
#             return trail;
#         }
#     </script>
# </body>
# </html>

# %% [markdown]
# # 🐍 Ejercicios de Python Básico - ¡Tu Primera Aventura en Programación!
#
# > **¡Bienvenido/a al mundo de Python!** 🚀
# > Estos ejercicios te llevarán paso a paso desde cero hasta convertirte en un verdadero manipulador de datos y código.
#
# ---

# %% [markdown]
# ## 🎯 **Misión 1: El Laboratorio de Variables**
# *Donde aprenderás a crear y almacenar información como un científico de datos*

# %% [markdown]
# ### 🧪 **Experimento 1.1: Creando tu Identidad Digital**
#
# 🎭 Crea tu avatar digital con estas variables:
# - 🏷️ nombre: ¿Cómo te llamas? (string)
# - 🎂 edad: ¿Cuántos años tienes? (integer)
# - 📏 altura: ¿Cuánto mides en metros? (float)
# - 🎓 es_estudiante: ¿Estás estudiando? (boolean)
# - 📚 materias_favoritas: 3 materias que te gustan (list)
# - 🗂️ mi_perfil: toda tu info en un diccionario (dict)

# %%
# ✨ Tu código mágico aquí:

# %% [markdown]
# ### 🔍 **Experimento 1.2: Detective de Tipos**
#
# 🕵️ Usa type() para descubrir la identidad secreta de cada variable
# ¿Será un string disfrazado de número? ¡Averígualo!

# %%
# 🔎 Tu investigación aquí:

# %% [markdown]
# ### ⚡ **Experimento 1.3: La Máquina Transformadora**

# %%
# 🎭 Transforma estos valores usando tu magia de conversión:
super_numero = "456"      # 🎯 Conviértelo a entero
precio_secreto = "78.99"  # 💰 Conviértelo a float  
años_exactos = 30.0       # 🔢 Conviértelo a entero
codigo_agente = 007       # 🕴️ Conviértelo a string

# %%
# 🪄 Tu magia transformadora aquí:

# %% [markdown]
# ---
# ## 🎨 **Misión 2: El Arte de las Palabras**
# *Conviértete en un maestro manipulador de texto*

# %% [markdown]
# ### 🎪 **Desafío 2.1: El Gran Espectáculo de Concatenación**

# %%
# 🎭 Los protagonistas de nuestro show:
nombre = "Alex"
apellido = "Coder"
edad = 25

# 🎬 Crea estos espectáculos:
# 1. 🤝 Une nombre y apellido con un abrazo (espacio)
# 2. 📢 Crea un anuncio: "¡Hola mundo! Soy [nombre completo] y tengo [edad] años"
# 3. 🚀 Usa f-strings para crear el mismo anuncio, ¡u otro!, de forma más elegante!

# %%
# 🎨 Tu obra maestra aquí:

# %% [markdown]
# ### 🎭 **Desafío 2.2: La Transformación Mágica de Textos**

# %%
mensaje_loco = "PyThOn Es EL LeNgUaJe MáS GenIaL DeL UnIvErSo"

# 🎯 Realiza estas transformaciones espectaculares:
# 1. 📢 ¡TODO EN MAYÚSCULAS COMO SI GRITARAS!
# 2. 🤫 todo en minúsculas como un susurro
# 3. 👑 Formato Título Como Un Rey
# 4. 📖 Solo la primera letra mayúscula
# 5. 🔄 Intercambio mayús-minus (¡efecto espejo!)

# %%
# 🪄 Tu laboratorio de transformaciones:

# %% [markdown]
# ### 🕵️ **Desafío 2.3: El Detective de Palabras**

# %%
misterio = "El dragón dorado vuela sobre el castillo, el dragón regresa al amanecer"

# 🔍 Resuelve este misterio:
# 1. 🐉 ¿El "dragón" está en esta historia?
# 2. 🔢 ¿Cuántas veces aparece "dragón"?
# 3. 🏰 ¿En qué posición aparece "castillo" por primera vez?
# 4. 🐉 ¿Cuál es la última posición de "dragón"?
# 5. 🌅 ¿La historia comienza con "El"?
# 6. 🌅 ¿La historia termina con "amanecer"?

# %%
# 🕵️ Tu investigación detectivesca:

# %% [markdown]
# ### ✂️ **Desafío 2.4: El Cirujano de Strings**

# %%
email_misterioso = "hackerpro@codingninja.com"
telefono_secreto = "555-123-4567"

# 🔬 Extrae con precisión quirúrgica:
# 1. 👤 El nombre de usuario del email (antes del @)
# 2. 🌐 El dominio del email (después del @) 
# 3. 📱 El código de área del teléfono (primeros 3 números)
# 4. 🎯 Los primeros 5 caracteres del email
# 5. 🎯 Los últimos 4 caracteres del email

# %%
# ⚔️ Tu precisión ninja aquí:

# %% [markdown]
# ### 🛠️ **Desafío 2.5: El Taller de Cadenas Avanzado**

# %%
texto_desprolijo = "   Programar es súper divertido   "
palabras_sueltas = ["Código", "limpio", "es", "arte"]

# 🔧 Usa tus herramientas profesionales:
# 1. ✨ Limpia los espacios molestos del texto
# 2. 🔪 Corta el texto en palabras individuales  
# 3. 🔗 Une las palabras sueltas con guiones elegantes
# 4. 🔄 Cambia "divertido" por "INCREÍBLE"

# %%
# 🛠️ Tu taller profesional:

# %% [markdown]
# ---
# ## 🧮 **Misión 3: Los Poderes de los Operadores**
# *Desbloquea los superpoderes matemáticos y lógicos*

# %% [markdown]
# ### ➕ **Batalla 3.1: Arena Matemática**

# %%
guerrero_a = 42
guerrero_b = 7

# ⚔️ ¡Que comience la batalla matemática!
# 1. ➕ Suma de fuerzas
# 2. ➖ Diferencia de poder  
# 3. ✖️ Multiplicación de energía
# 4. ➗ División de recursos (con decimales)
# 5. 🏴 División entera (sin decimales)
# 6. 🎯 El resto de la división (módulo)
# 7. 🚀 Potencia explosiva (a^b)

# %%
# ⚔️ Tu campo de batalla:

# %% [markdown]
# ### ⚖️ **Batalla 3.2: El Tribunal de Comparaciones**

# %%
heroe = 50
villano = 80  
sidekick = 50

# 👨‍⚖️ Emite tu veredicto (True/False):
# 1. ⚡ ¿El héroe es igual de fuerte que el villano?
# 2. ❌ ¿El héroe es diferente del villano?
# 3. 📉 ¿El héroe es más débil que el villano?
# 4. 📈 ¿El héroe es más fuerte que el villano?
# 5. 🤝 ¿El héroe tiene al menos la fuerza del sidekick?
# 6. 💪 ¿El villano es al menos tan fuerte como el héroe?

# %%
# ⚖️ Tu sala del juicio:

# %% [markdown]
# ### 🧠 **Batalla 3.3: La Matrix Lógica**

# %%
poder_fuego = True
poder_hielo = False  
poder_rayo = True

# 🤖 Descifra la matrix lógica:
# 1. 🔥❄️ poder_fuego AND poder_hielo
# 2. 🔥❄️ poder_fuego OR poder_hielo  
# 3. 🚫 NOT poder_fuego
# 4. 🌪️ (poder_fuego AND poder_rayo) OR poder_hielo
# 5. 🔄 NOT (poder_fuego OR poder_hielo)
# 6. ⚡ (poder_fuego AND poder_hielo) OR (poder_rayo AND NOT poder_hielo)

# 🧠 Tu decodificador mental:

# %% [markdown]
# ### 🔄 **Batalla 3.4: Transformaciones de Asignación**

# %%
puntos = 100

# 🎮 Aplica estos power-ups secuenciales:
# 1. 🆙 Gana 25 puntos extra
# 2. 💥 Duplica tus puntos  
# 3. 😵 Pierdes un tercio por una trampa
# 4. 🚀 Eleva tus puntos al cuadrado
# ¡Muestra tu progreso después de cada transformación!

# 🎮 Tu consola de juego:

# %% [markdown]
# ### 🔍 **Batalla 3.5: Los Detectores Especiales**

# %%
arsenal_1 = [10, 20, 30]
arsenal_2 = [10, 20, 30]  
arsenal_gemelo = arsenal_1
palabra_clave = "PYTHON"
numeros_magicos = [1, 3, 5, 7, 9]

# 🔍 Usa tus detectores especiales:
# 1. 👯 ¿arsenal_1 ES EXACTAMENTE arsenal_2? (identidad)
# 2. 🪞 ¿arsenal_1 ES EXACTAMENTE arsenal_gemelo?
# 3. ❌ ¿arsenal_1 NO ES arsenal_2?
# 4. 📝 ¿La letra "P" está EN palabra_clave?
# 5. ❓ ¿La letra "Z" está EN palabra_clave?  
# 6. 🎯 ¿El número 5 está EN numeros_magicos?
# 7. 🚫 ¿El número 8 NO está EN numeros_magicos?

# 🕵️ Tu laboratorio de detección:

# %% [markdown]
# ---
# ## 🏆 **Misión Final: Los Desafíos del Maestro**
# *Combina todos tus poderes en estas épicas batallas finales*

# %% [markdown]
# ### 📊 **Desafío Final 1: El Analizador Supremo**

# %%
# 🎯 Tu objetivo: analizar esta frase misteriosa
frase_secreta = "Python es el lenguaje más poderoso del universo tecnológico"

# 🔬 Tu misión de análisis completo:
# 1. 📏 ¿Cuántos caracteres tiene esta revelación?
# 2. 📢🤫 Muéstrala en MAYÚSCULAS y minúsculas
# 3. 📝 ¿Cuántas palabras contiene este mensaje?
# 4. 💪 ¿Contiene la palabra "poderoso"?
# 5. 🔄 Sustituye "Python" por "JavaScript" (¡herejía!)
# 6. ✂️ Extrae las primeras 3 y últimas 3 palabras

# 🔬 Tu laboratorio de análisis supremo:

# %% [markdown]
# ### 🧮 **Desafío Final 2: La Calculadora del Futuro**

# %%
# 🚀 Los números del destino:
numero_del_destino = 89
numero_de_la_suerte = 13

# ⚡ Crea la calculadora más épica:
# 1. 🤔 ¿Cuál es más poderoso?
# 2. ⚖️ ¿Son números gemelos (iguales)?
# 3. 🧮 Realiza TODAS las operaciones matemáticas épicas
# 4. 🎯 ¿El número del destino es múltiplo perfecto del de la suerte?
# 5. 💫 Combina todo en un super análisis

# 🧮 Tu calculadora del futuro:

# %% [markdown]
# ### 🛡️ **Desafío Final 3: El Guardián Validador**

# %%
# 🛡️ Los datos a proteger:
nombre_agente = "CyberNinja42"
clave_secreta = "SuperSecreta2024!"
edad_agente = 28

# 🔒 Tu sistema de seguridad supremo debe verificar:
# 1. 📏 ¿El nombre del agente tiene entre 6 y 20 caracteres?
# 2. 🔐 ¿La clave tiene al menos 10 caracteres?
# 3. 🔢 ¿La clave contiene números secretos?
# 4. 🎂 ¿El agente es mayor de edad (≥ 18)?
# 5. ✅ ¿TODAS las validaciones son exitosas?
# 6. 🚨 Crea un reporte de seguridad completo

# 🛡️ Tu fortaleza de validación:

# %% [markdown]
# ---
# ## 💡 **Banco de Soluciones Secretas**

# %% [markdown]
# ### 🗝️ **Solución Secreta 1.1:**

# %%
# 🎭 Mi avatar digital:
nombre = "Alex"
edad = 22
altura = 1.75
es_estudiante = True
materias_favoritas = ["Python", "IA", "Ciberseguridad"]
mi_perfil = {"nombre": "Alex", "edad": 22, "ciudad": "TechCity", "superpoder": "Coding"}

# %% [markdown]
# ### 🗝️ **Solución Secreta 2.1:**

# %%
# 🎪 El gran espectáculo:
nombre = "Alex"
apellido = "Coder"
edad = 25

nombre_completo = nombre + " " + apellido
anuncio_clasico = "¡Hola mundo! Soy " + nombre_completo + " y tengo " + str(edad) + " años"
anuncio_moderno = f"¡Hola mundo! Soy {nombre_completo} y tengo {edad} años"
print("🎬", anuncio_moderno)

# %% [markdown]
# ### 🗝️ **Solución Secreta 2.3:**

# %%
# 🕵️ Resolviendo el misterio:
misterio = "El dragón dorado vuela sobre el castillo, el dragón regresa al amanecer"

print("🐉 ¿Dragón en la historia?", "dragón" in misterio)                    
print("🔢 Apariciones de dragón:", misterio.count("dragón"))                
print("🏰 Primera posición de castillo:", misterio.find("castillo"))        
print("🐉 Última posición de dragón:", misterio.rfind("dragón"))           
print("🌅 ¿Empieza con 'El'?", misterio.startswith("El"))              
print("🌅 ¿Termina con 'amanecer'?", misterio.endswith("amanecer"))

# %% [markdown]
# ---
# ## 🎯 **Consejos del Sensei para el Instructor**
#
# ### 🚀 **Estrategias de Enseñanza Épicas:**
#
# 1. **🎮 Gamificación Total**: Presenta cada ejercicio como una misión o batalla
# 2. **🎭 Storytelling**: Cada concepto tiene una narrativa emocionante
# 3. **🏆 Progresión de Logros**: Los estudiantes "desbloquean" habilidades
# 4. **💥 Errores = Experiencia**: Los bugs son "jefes finales" a derrotar
# 5. **🤝 Trabajo en Equipo**: Fomenta la colaboración tipo "guild"
#
# ### 🛠️ **Herramientas del Ninja Instructor:**
# - ✨ Usa emojis para crear ambiente visual
# - 🎯 Celebra cada pequeño triunfo
# - 🚀 Relaciona conceptos con tecnología actual
# - 🎪 Haz demostraciones en vivo tipo "show"
# - 💡 Comparte "secretos del código" como tips especiales
#
# ### 🎊 **¡El código no es solo lógica, es creatividad pura!** 🎊
